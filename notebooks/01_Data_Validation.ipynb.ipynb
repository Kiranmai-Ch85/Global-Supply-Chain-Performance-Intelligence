# %% [markdown]
# **Project** Enterprise Procurement & Vendor Performance Analytics
#
# ## Data Validation Report

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Admin\Downloads\Vendor Performance Analysis\purchases_sample.csv")

# %%
df.head()
# Out:
#            InventoryId  Store  Brand                   Description   Size  \
# 0      54_GUTHRAM_2057     54   2057  Rebel Yell Root Beer Bourbon   50mL
# 1   76_DONCASTER_21609     76  21609       Josh Cellars Legacy Red  750mL
# 2  64_CESTERFIELD_5090     64   5090      El Charro Silver Tequila  750mL
# 3    73_DONCASTER_3915     73   3915          Sauza Silver Tequila  750mL
# 4    57_LANTEGLOS_3041     57   3041    Zhenka Pink Lemonade Vodka  1.75L
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0          8352  LUXCO INC                       11719  2024-08-19
# 1          4425        MARTIGNETTI COMPANIES     11928  2024-09-02
# 2          8004  SAZERAC CO INC                  12476  2024-10-05
# 3         12546  JIM BEAM BRANDS COMPANY         12222  2024-09-22
# 4          9552  M S WALKER INC                  12115  2024-09-15
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %%
## to display last five rows
df.tail()
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 19995  76_DONCASTER_14805     76  14805  Ninety+Cellars Lot 23 Malbec  750mL
# 19996  34_PITMERDEN_20402     34  20402       I Lauri Tavo Pnt Grigio  750mL
# 19997   76_DONCASTER_1962     76   1962                Jim Beam Apple  750mL
# 19998    30_CULCHETH_5138     30   5138      Fireball Cinnamon Whisky  750mL
# 19999    60_IRRAGIN_28069     60  28069        Sutter Home Merlot Cal   1.5L
#
#        VendorNumber                   VendorName  PONumber      PODate  \
# 19995          4950  LATITUDE BEVERAGE COMPANY       12677  2024-10-19
# 19996          7255                   PSP WINES      10803  2024-06-23
# 19997         12546  JIM BEAM BRANDS COMPANY         10007  2024-04-29
# 19998          8004  SAZERAC CO INC                  11390  2024-07-27
# 19999          8892  TRINCHERO FAMILY ESTATES        13591  2024-12-19
#
# ...

# %%
df.shape
# Out:
# (20000, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   InventoryId     20000 non-null  object
#  1   Store           20000 non-null  int64
#  2   Brand           20000 non-null  int64
#  3   Description     20000 non-null  object
#  4   Size            20000 non-null  object
#  5   VendorNumber    20000 non-null  int64
#  6   VendorName      20000 non-null  object
#  7   PONumber        20000 non-null  int64
#  8   PODate          20000 non-null  object
#  9   ReceivingDate   20000 non-null  object
#  10  InvoiceDate     20000 non-null  object
#  11  PayDate         20000 non-null  object
#  12  PurchasePrice   20000 non-null  float64
#  13  Quantity        20000 non-null  int64
#  14  Dollars         20000 non-null  float64
#  15  Classification  20000 non-null  int64
# dtypes: float64(2), int64(6), object(8)
# ...

# %%
df.columns.tolist()
# Out:
# ['InventoryId',
#  'Store',
#  'Brand',
#  'Description',
#  'Size',
#  'VendorNumber',
#  'VendorName',
#  'PONumber',
#  'PODate',
#  'ReceivingDate',
#  'InvoiceDate',
#  'PayDate',
#  'PurchasePrice',
#  'Quantity',
#  'Dollars',
#  'Classification']

# %%
df.dtypes
# Out:
# InventoryId        object
# Store               int64
# Brand               int64
# Description        object
# Size               object
# VendorNumber        int64
# VendorName         object
# PONumber            int64
# PODate             object
# ReceivingDate      object
# InvoiceDate        object
# PayDate            object
# PurchasePrice     float64
# Quantity            int64
# Dollars           float64
# Classification      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# InventoryId       0
# Store             0
# Brand             0
# Description       0
# Size              0
# VendorNumber      0
# VendorName        0
# PONumber          0
# PODate            0
# ReceivingDate     0
# InvoiceDate       0
# PayDate           0
# PurchasePrice     0
# Quantity          0
# Dollars           0
# Classification    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              Store         Brand   VendorNumber      PONumber  PurchasePrice  \
# count  20000.00000  20000.000000   20000.000000  20000.000000   20000.000000
# mean      44.54355  12330.570900    6804.535000  11051.167450      12.198253
# std       23.50774  12491.277964    7731.260846   1569.321217      35.796257
# min        1.00000     58.000000       2.000000   8106.000000       0.000000
# 25%       24.00000   3650.750000    3252.000000   9758.750000       6.120000
# 50%       48.00000   6479.000000    4425.000000  11128.000000       9.200000
# 75%       67.00000  18772.000000    9552.000000  12415.000000      14.390000
# max       81.00000  90609.000000  173357.000000  13661.000000    4264.700000
#
#            Quantity       Dollars  Classification
# count  20000.000000  20000.000000    20000.000000
# mean      14.503750    140.198950        1.439200
# std       24.600932    339.071278        0.496302
# min        1.000000      0.000000        1.000000
# ...

# %%
df.describe(include='object')
# Out:
#               InventoryId            Description   Size  \
# count               20000                  20000  20000
# unique              17624                   3378     35
# top     76_DONCASTER_3348  Tito's Handmade Vodka  750mL
# freq                    6                    163  10163
#
#                          VendorName      PODate ReceivingDate InvoiceDate  \
# count                         20000       20000         20000       20000
# unique                          102         319           326         370
# top     DIAGEO NORTH AMERICA INC     2024-06-27    2024-09-29  2024-08-16
# freq                           2076         211           170         244
#
#            PayDate
# count        20000
# unique         381
# top     2024-09-22
# freq           180

# %%
df.nunique()
# Out:
# InventoryId       17624
# Store                80
# Brand              3880
# Description        3378
# Size                 35
# VendorNumber        100
# VendorName          102
# PONumber           2555
# PODate              319
# ReceivingDate       326
# InvoiceDate         370
# PayDate             381
# PurchasePrice      1144
# Quantity            187
# Dollars            5457
# Classification        2
# dtype: int64

# %%
import pandas as pd

def validate(df, name):
    print("="*80)
    print(f"Dataset : {name}")
    print("="*80)

    print("\nShape")
    print(df.shape)

    print("\nFirst 5 Rows")
    display(df.head())

    print("\nLast 5 Rows")
    display(df.tail())

    print("\nInformation")
    df.info()

    print("\nMissing Values")
    print(df.isnull().sum())

    print("\nDuplicate Records")
    print(df.duplicated().sum())

    print("\nData Types")
    print(df.dtypes)

    print("\nSummary")
    display(df.describe(include='all'))

    print("\nUnique Values")
    print(df.nunique())

# %%
sales = pd.read_csv(r"C:\Users\Admin\Downloads\Vendor Performance Analysis\sales_sample.csv")

validate(sales,"Sales Sample")
# Out:
# ...
# Dataset : Sales Sample
# ...
#
# Shape
# (20000, 14)
#
# First 5 Rows
#           InventoryId  Store  Brand                 Description   Size  \
# 0    14_BROMWICH_8200     14   8200  Chambord Liqueur de France   50mL
# 1  69_MOUNTMEND_21019     69  21019            Black Box Pnt Nr     3L
# 2   69_MOUNTMEND_7143     69   7143   Smirnoff Watermelon Vodka  1.75L
# 3  19_WINTERVALE_6590     19   6590    Almaden B/B Wh Znfdl Cal     5L
# 4    53_HILLFAR_34133     53  34133   Turning Leaf RSV Cab Svgn   1.5L
#
#    SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0              1          2.99        2.99  2024-01-16    50.0
# 1              1         18.99       18.99  2024-04-07  3000.0
# 2              1         19.99       19.99  2024-07-28  1750.0
# 3              2         29.98       14.99  2024-07-01  5000.0
# 4              1          9.99        9.99  2024-05-14  1500.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# ...

# %%
Purchase_prices = pd.read_csv(r"C:\Users\Admin\Downloads\Vendor Performance Analysis\purchase_prices.csv")

validate(Purchase_prices,"Purchase prices")
# Out:
# ...
# Dataset : Purchase prices
# ...
#
# Shape
# (12261, 9)
#
# First 5 Rows
#    Brand                  Description  Price   Size Volume  Classification  \
# 0     58  Gekkeikan Black & Gold Sake  12.99  750mL    750               1
# 1     62     Herradura Silver Tequila  36.99  750mL    750               1
# 2     63   Herradura Reposado Tequila  38.99  750mL    750               1
# 3     72         No. 3 London Dry Gin  34.99  750mL    750               1
# 4     75    Three Olives Tomato Vodka  14.99  750mL    750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.28          8320  SHAW ROSS INT L IMP LTD
# 1          28.67          1128  BROWN-FORMAN CORP
# 2          30.46          1128  BROWN-FORMAN CORP
# 3          26.11          9165  ULTRA BEVERAGE COMPANY LLP
# 4          10.94          7245  PROXIMO SPIRITS INC.
# Last 5 Rows
#        Brand                   Description  Price    Size Volume  \
# ...

# %%
df.shape
# Out:
# (20000, 16)

# %%
vendor_invoice = pd.read_csv(r"C:\Users\Admin\Downloads\Vendor Performance Analysis\vendor_invoice.csv")

validate(vendor_invoice,"vendor invoice")
# Out:
# ...
# Dataset : vendor invoice
# ...
#
# Shape
# (5543, 10)
#
# First 5 Rows
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2024-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2024-01-09      8169
# 3           480  BACARDI USA INC              2024-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2024-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval
# 0  2023-12-21  2024-02-16         6     214.26     3.47      NaN
# 1  2023-12-22  2024-02-21        15     140.55     8.57      NaN
# 2  2023-12-24  2024-02-16         5     106.60     4.61      NaN
# 3  2023-12-20  2024-02-05     10100  137483.78  2935.20      NaN
# 4  2023-12-24  2024-02-12      1935   15527.25   429.20      NaN
# Last 5 Rows
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# ...

# %%
vendor_sales_summary = pd.read_csv(r"C:\Users\Admin\Downloads\Vendor Performance Analysis\vendor_sales_summary.csv")

validate(vendor_sales_summary,"vendor sales summary")
# Out:
# ...
# Dataset : vendor sales summary
# ...
#
# Shape
# (10692, 18)
#
# First 5 Rows
#    VendorNumber                VendorName  Brand              Description  \
# 0          1128         BROWN-FORMAN CORP   1233  Jack Daniels No 7 Black
# 1          4425     MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035         PERNOD RICARD USA   8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC   4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC   3545          Ketel One Vodka
#
#    PurchasePrice  ActualPrice  Volume  TotalPurchaseQuantity  \
# 0          26.27        36.99  1750.0                 145080
# 1          23.19        28.99  1750.0                 164038
# 2          18.24        24.99  1750.0                 187407
# 3          16.17        22.99  1750.0                 201682
# 4          21.89        29.99  1750.0                 138109
#
#    TotalPurchaseDollars  TotalSalesQuantity  TotalSalesPrice  \
# ...

# %%
begin_inventory = pd.read_csv(r"C:\Users\Admin\Downloads\Vendor Performance Analysis\begin_inventory.csv")

validate(begin_inventory,"begin inventory")
# Out:
# ...
# Dataset : begin inventory
# ...
#
# Shape
# (206529, 9)
#
# First 5 Rows
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01
# Last 5 Rows
#                InventoryId  Store       City  Brand  \
# 206524  79_BALLYMENA_46985     79  BALLYMENA  46985
# 206525  79_BALLYMENA_47014     79  BALLYMENA  47014
# ...

# %%
end_inventory = pd.read_csv(r"C:\Users\Admin\Downloads\Vendor Performance Analysis\end_inventory.csv")

validate(end_inventory,"end inventory")
# Out:
# ...
# Dataset : end inventory
# ...
#
# Shape
# (224489, 9)
#
# First 5 Rows
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 2  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 3  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
# 4  1_HARDERSFIELD_75      1  HARDERSFIELD     75    Three Olives Tomato Vodka
#
#     Size  onHand  Price     endDate
# 0  750mL      11  12.99  2024-12-31
# 1  750mL       7  36.99  2024-12-31
# 2  750mL       7  38.99  2024-12-31
# 3  750mL       4  34.99  2024-12-31
# 4  750mL       7  14.99  2024-12-31
# Last 5 Rows
#               InventoryId  Store      City  Brand  \
# 224484  81_PEMBROKE_90087     81  PEMBROKE  90087
# 224485  81_PEMBROKE_90088     81  PEMBROKE  90088
# ...

# %%
Procurement_KPI_Analysis_Dataset = pd.read_csv(r"C:\Users\Admin\Documents\Procurement KPI Analysis Dataset\Procurement_KPI_Analysis_Dataset.csv")

validate(Procurement_KPI_Analysis_Dataset,"Procurement KPI Analysis Dataset")
# Out:
# ...
# Dataset : Procurement KPI Analysis Dataset
# ...
#
# Shape
# (777, 11)
#
# First 5 Rows
#       PO_ID         Supplier  Order_Date Delivery_Date    Item_Category  \
# 0  PO-00001        Alpha_Inc  2023-10-17    2023-10-25  Office Supplies
# 1  PO-00002  Delta_Logistics  2022-04-25    2022-05-05  Office Supplies
# 2  PO-00003         Gamma_Co  2022-01-26    2022-02-15              MRO
# 3  PO-00004    Beta_Supplies  2022-10-09    2022-10-28        Packaging
# 4  PO-00005  Delta_Logistics  2022-09-08    2022-09-20    Raw Materials
#
#   Order_Status  Quantity  Unit_Price  Negotiated_Price  Defective_Units  \
# 0    Cancelled      1176       20.13             17.81              NaN
# 1    Delivered      1509       39.32             37.34            235.0
# 2    Delivered       910       95.51             92.26             41.0
# 3    Delivered      1344       99.85             95.52            112.0
# 4    Delivered      1180       64.07             60.53            171.0
#
#   Compliance
# ...

# %%
purchase_orders = pd.read_csv(r"C:\Users\Admin\Documents\Aerospace Supply Chain Performance & Forecasting\purchase_orders.csv")

validate(purchase_orders,"purchase orders")
# Out:
# ...
# Dataset : purchase orders
# ...
#
# Shape
# (29666, 9)
#
# First 5 Rows
#       po_id supplier_id site_id part_id  order_date promised_date  \
# 0  PO000001      SUP004  SITE01  P00001  2022-05-02    2022-05-28
# 1  PO000002      SUP004  SITE01  P00001  2022-07-04    2022-07-31
# 2  PO000003      SUP004  SITE01  P00001  2022-10-17    2022-11-12
# 3  PO000004      SUP004  SITE01  P00001  2023-02-06    2023-03-07
# 4  PO000005      SUP004  SITE01  P00001  2023-04-03    2023-04-28
#
#   receipt_date  ordered_qty  received_qty
# 0   2022-05-29           16            16
# 1   2022-08-02            5             5
# 2   2022-11-16            5             5
# 3   2023-03-09            3             3
# 4   2023-04-29            5             5
# Last 5 Rows
#           po_id supplier_id site_id part_id  order_date promised_date  \
# 29661  PO029662      SUP035  SITE06  P00300  2024-08-12    2024-09-13
# 29662  PO029663      SUP035  SITE06  P00300  2024-08-19    2024-09-20
# ...

# %%
Supply_Chain_Operations_Dataset = pd.read_csv(r"C:\Users\Admin\Documents\Supply Chain Operations Dataset\Supply_Chain_Operations_Dataset.csv")

validate(Supply_Chain_Operations_Dataset,"Supply Chain Operations Dataset")
# Out:
# ...
# Dataset : Supply Chain Operations Dataset
# ...
#
# Shape
# (30, 7)
#
# First 5 Rows
#     Product    Supplier Warehouse Location  Quantity  Unit Price  Total Cost  \
# 0  Widget A  Alpha Corp        Warehouse 3        45       16.02      720.90
# 1  Widget A  Epsilon Co        Warehouse 1        85       23.99     2039.15
# 2  Widget A    Beta Ltd        Warehouse 1        74       32.09     2374.66
# 3  Widget B  Epsilon Co        Warehouse 2        38       25.21      957.98
# 4  Widget A    Beta Ltd        Warehouse 3        64       20.31     1299.84
#
#   Delivery Date
# 0    2025-06-05
# 1    2025-06-01
# 2    2025-06-18
# 3    2025-06-09
# 4    2025-06-05
# Last 5 Rows
#      Product    Supplier Warehouse Location  Quantity  Unit Price  Total Cost  \
# 25    Tool Z  Epsilon Co        Warehouse 1        29       21.83      633.07
# 26    Tool Z  Epsilon Co        Warehouse 1        86       19.59     1684.74
# ...

# %% [markdown]
# ## Data Reliability

# %% [markdown]
# ## Data Source Reliability
#
# - Source: Public Kaggle Datasets
# - Dataset Type: Synthetic / Semi-Synthetic
# - Domain: Procurement, Vendor Management, Inventory, and Supply Chain
# - Purpose: Educational analytics and business intelligence projects
#
# ## Reliability Assessment
#
# The datasets were evaluated for reliability using the following criteria:
#
# - Dataset structure validation
# - Missing value analysis
# - Duplicate record detection
# - Data type verification
# - Statistical summary review
# - Column consistency verification
# - Business relevance assessment
#
# Although the datasets are synthetic or semi-synthetic, they represent realistic enterprise
# procurement and supply chain scenarios suitable for analytical modeling and dashboard development.

# %% [markdown]
# ## Dataset Limitations

# %% [markdown]
# # Dataset Limitations
#
# - The datasets are publicly available and are not collected directly from a live ERP system.
# - Some datasets are synthetic or semi-synthetic and may not fully represent real organizational data.
# - Different datasets originate from different sources and require integration during data preparation.
# - Some columns may contain missing values or inconsistent formats that will be addressed during the data cleaning phase.

# %% [markdown]
# ## validation Conclusion

# %%
# Validation Conclusion

The project datasets were successfully validated for structure, completeness, consistency, and statistical characteristics.

The validation process confirmed that the datasets are appropriate for procurement analytics, vendor performance analysis, inventory analysis, and supply chain analysis.

Any data quality issues identified during validation will be handled in the data cleaning stage before data integration and analysis.

# %% [markdown]
# ## Correlation Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Admin\Downloads\Vendor Performance Analysis\purchases_sample.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   InventoryId     20000 non-null  object
#  1   Store           20000 non-null  int64
#  2   Brand           20000 non-null  int64
#  3   Description     20000 non-null  object
#  4   Size            20000 non-null  object
#  5   VendorNumber    20000 non-null  int64
#  6   VendorName      20000 non-null  object
#  7   PONumber        20000 non-null  int64
#  8   PODate          20000 non-null  object
#  9   ReceivingDate   20000 non-null  object
#  10  InvoiceDate     20000 non-null  object
#  11  PayDate         20000 non-null  object
#  12  PurchasePrice   20000 non-null  float64
#  13  Quantity        20000 non-null  int64
#  14  Dollars         20000 non-null  float64
#  15  Classification  20000 non-null  int64
# dtypes: float64(2), int64(6), object(8)
# ...

# %%
numeric_columns = purchases.select_dtypes(include=['number'])

print("Numeric Columns:")
print(numeric_columns.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 numeric_columns = purchases.select_dtypes(include=['number'])
#       3 print("Numeric Columns:")
#       4 print(numeric_columns.columns.tolist())
#
# NameError: name 'purchases' is not defined

# %%
# %whos
# Out:
# Variable                           Type         Data/Info
# ---------------------------------------------------------
# Procurement_KPI_Analysis_Dataset   DataFrame            PO_ID         Sup<...>\n[777 rows x 11 columns]
# Purchase_prices                    DataFrame           Brand             <...>n[12261 rows x 9 columns]
# Supply_Chain_Operations_Dataset    DataFrame         Product    Supplier <...>-25  \n29    2025-06-18
# begin_inventory                    DataFrame                   InventoryI<...>[206529 rows x 9 columns]
# dataframe_columns                  function     <function dataframe_colum<...>ns at 0x000002546FB92FC0>
# dataframe_hash                     function     <function dataframe_hash at 0x00000254687FCCC0>
# df                                 DataFrame                   InventoryI<...>[20000 rows x 16 columns]
# dtypes_str                         function     <function dtypes_str at 0x00000254687DBEC0>
# ...

# %%
# Rename the dataframe

purchases = df.copy()

# %%
purchases.head()
# Out:
#            InventoryId  Store  Brand                   Description   Size  \
# 0      54_GUTHRAM_2057     54   2057  Rebel Yell Root Beer Bourbon   50mL
# 1   76_DONCASTER_21609     76  21609       Josh Cellars Legacy Red  750mL
# 2  64_CESTERFIELD_5090     64   5090      El Charro Silver Tequila  750mL
# 3    73_DONCASTER_3915     73   3915          Sauza Silver Tequila  750mL
# 4    57_LANTEGLOS_3041     57   3041    Zhenka Pink Lemonade Vodka  1.75L
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0          8352  LUXCO INC                       11719  2024-08-19
# 1          4425        MARTIGNETTI COMPANIES     11928  2024-09-02
# 2          8004  SAZERAC CO INC                  12476  2024-10-05
# 3         12546  JIM BEAM BRANDS COMPANY         12222  2024-09-22
# 4          9552  M S WALKER INC                  12115  2024-09-15
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %% [markdown]
# ## Numeric columns

# %%
numeric_columns = purchases.select_dtypes(include=['number'])

print("Numeric Columns:")
print(numeric_columns.columns.tolist())
# Out:
# Numeric Columns:
# ['Store', 'Brand', 'VendorNumber', 'PONumber', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification']

# %%
## Select Continuous Numerical Variables
corr_data = purchases[['PurchasePrice',
                       'Quantity',
                       'Dollars']]

corr_data.head()
# Out:
#    PurchasePrice  Quantity  Dollars
# 0           0.77       120    92.40
# 1           9.58        12   114.96
# 2          10.23        12   122.76
# 3           9.48        24   227.52
# 4           5.83         5    29.15

# %%
## Calculate Correlation Matrix
correlation_matrix = corr_data.corr()

correlation_matrix
# Out:
#                PurchasePrice  Quantity   Dollars
# PurchasePrice       1.000000 -0.041702  0.166190
# Quantity           -0.041702  1.000000  0.646364
# Dollars             0.166190  0.646364  1.000000

# %%
## Correlation Heatmap
plt.figure(figsize=(6,5))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title("Correlation Matrix - Purchases Dataset")

plt.show()

# %%
# Display the correlation matrix
print(correlation_matrix)
# Out:
#                PurchasePrice  Quantity   Dollars
# PurchasePrice       1.000000 -0.041702  0.166190
# Quantity           -0.041702  1.000000  0.646364
# Dollars             0.166190  0.646364  1.000000

# %% [markdown]
# ## Correlation Analysis Observation
# ## 1. PurchasePrice and Quantity
# Correlation coefficient: -0.04
# This indicates a very weak negative correlation.
# The purchase price has almost no linear relationship with the quantity purchased.
# ## 2. PurchasePrice and Dollars
# Correlation coefficient: 0.17
# This indicates a weak positive correlation.
# As the purchase price increases, the total purchase amount (Dollars) tends to increase slightly.
# ## 3. Quantity and Dollars
# Correlation coefficient: 0.65
# This indicates a moderate to strong positive correlation.
# Higher purchase quantities generally result in higher total procurement costs, which aligns with expected business behavior.
# ## 4. Business Insight
# The strongest relationship is between Quantity and Dollars, suggesting that purchase quantity is a major driver of procurement expenditure.
# The observed relationships are logical and consistent with procurement operations.

# %% [markdown]
# ## Business Logic Validation

# %%
# Check for invalid Purchase Prices
print("Negative Purchase Prices:", (purchases['PurchasePrice'] < 0).sum())
# Out:
# Negative Purchase Prices: 0

# %%
# Check for invalid Quantities
print("Negative Quantities:", (purchases['Quantity'] < 0).sum())
# Out:
# Negative Quantities: 0

# %%
# Check for invalid Dollar Values
print("Negative Dollar Values:", (purchases['Dollars'] < 0).sum())
# Out:
# Negative Dollar Values: 0

# %%
## date validation
date_columns = ['PODate', 'ReceivingDate', 'InvoiceDate', 'PayDate']

for col in date_columns:
    purchases[col] = pd.to_datetime(purchases[col], errors='coerce')

purchases[date_columns].isnull().sum()
# Out:
# PODate           0
# ReceivingDate    0
# InvoiceDate      0
# PayDate          0
# dtype: int64

# %% [markdown]
# ## Observation
# * Purchase Price contains no negative values.
# * Quantity contains no negative values.
# * Dollar values contain no negative values.
# * All date columns (PODate, ReceivingDate, InvoiceDate, and PayDate) were successfully converted to datetime format without generating missing values.
# * The dataset follows expected procurement business rules and is suitable for further analysis.

# %% [markdown]
# ## Dataset Reliability Conclusion
#
# The Purchases dataset was validated through structural checks, data quality assessment, correlation analysis, business logic validation, and date validation. No significant data quality issues were identified. The numerical relationships are logically consistent with procurement operations, and all date fields are valid. Although the dataset is semi-synthetic, it is reliable and suitable for procurement analytics after preprocessing.

# %% [markdown]
# ## Sales Data

# %%
sales.head()
# Out:
#           InventoryId  Store  Brand                 Description   Size  \
# 0    14_BROMWICH_8200     14   8200  Chambord Liqueur de France   50mL
# 1  69_MOUNTMEND_21019     69  21019            Black Box Pnt Nr     3L
# 2   69_MOUNTMEND_7143     69   7143   Smirnoff Watermelon Vodka  1.75L
# 3  19_WINTERVALE_6590     19   6590    Almaden B/B Wh Znfdl Cal     5L
# 4    53_HILLFAR_34133     53  34133   Turning Leaf RSV Cab Svgn   1.5L
#
#    SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0              1          2.99        2.99  2024-01-16    50.0
# 1              1         18.99       18.99  2024-04-07  3000.0
# 2              1         19.99       19.99  2024-07-28  1750.0
# 3              2         29.98       14.99  2024-07-01  5000.0
# 4              1          9.99        9.99  2024-05-14  1500.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# 0               1       0.05      1128  BROWN-FORMAN CORP
# ...

# %%
sales.shape
# Out:
# (20000, 14)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   InventoryId     20000 non-null  object
#  1   Store           20000 non-null  int64
#  2   Brand           20000 non-null  int64
#  3   Description     20000 non-null  object
#  4   Size            20000 non-null  object
#  5   SalesQuantity   20000 non-null  int64
#  6   SalesDollars    20000 non-null  float64
#  7   SalesPrice      20000 non-null  float64
#  8   SalesDate       20000 non-null  object
#  9   Volume          20000 non-null  float64
#  10  Classification  20000 non-null  int64
#  11  ExciseTax       20000 non-null  float64
#  12  VendorNo        20000 non-null  int64
#  13  VendorName      20000 non-null  object
# dtypes: float64(4), int64(5), object(5)
# memory usage: 2.1+ MB

# %%
sales.isnull().sum()
# Out:
# InventoryId       0
# Store             0
# Brand             0
# Description       0
# Size              0
# SalesQuantity     0
# SalesDollars      0
# SalesPrice        0
# SalesDate         0
# Volume            0
# Classification    0
# ExciseTax         0
# VendorNo          0
# VendorName        0
# dtype: int64

# %%
sales.duplicated().sum()
# Out:
# 0

# %%
sales.describe()
# Out:
#               Store         Brand  SalesQuantity  SalesDollars    SalesPrice  \
# count  20000.000000  20000.000000   20000.000000  20000.000000  20000.000000
# mean      43.632200  12159.797400       2.533200     34.077573     15.467199
# std       23.592941  12356.952573       3.764373     63.377212     12.862526
# min        1.000000     58.000000       1.000000      0.980000      0.490000
# 25%       23.000000   3681.750000       1.000000     10.990000      8.990000
# 50%       46.000000   6396.000000       1.000000     18.810000     12.990000
# 75%       66.000000  17826.750000       2.000000     34.990000     18.990000
# max       81.000000  90631.000000      93.000000   2184.570000    349.990000
#
#             Volume  Classification     ExciseTax       VendorNo
# count  20000.00000    20000.000000  20000.000000   20000.000000
# mean     937.90875        1.413850      1.435151    7211.545250
# std      695.38865        0.492535      3.538955    9045.237345
# ...

# %%
sales.nunique()
# Out:
# InventoryId       18418
# Store                80
# Brand              4100
# Description        3561
# Size                 38
# SalesQuantity        56
# SalesDollars       1158
# SalesPrice          190
# SalesDate           364
# Volume               21
# Classification        2
# ExciseTax           189
# VendorNo            101
# VendorName          104
# dtype: int64

# %%
numeric_columns = sales.select_dtypes(include=['number'])

print(numeric_columns.columns.tolist())
# Out:
# ['Store', 'Brand', 'SalesQuantity', 'SalesDollars', 'SalesPrice', 'Volume', 'Classification', 'ExciseTax', 'VendorNo']

# %%
## Select Continuous Numerical Variables
corr_data = sales[['SalesQuantity',
                   'SalesDollars',
                   'SalesPrice',
                   'Volume',
                   'ExciseTax']]

corr_data.head()
# Out:
#    SalesQuantity  SalesDollars  SalesPrice  Volume  ExciseTax
# 0              1          2.99        2.99    50.0       0.05
# 1              1         18.99       18.99  3000.0       0.45
# 2              1         19.99       19.99  1750.0       1.84
# 3              2         29.98       14.99  5000.0       1.50
# 4              1          9.99        9.99  1500.0       0.22

# %%
## Calculate Correlation Matrix
correlation_matrix = corr_data.corr()

print(correlation_matrix)
# Out:
#                SalesQuantity  SalesDollars  SalesPrice    Volume  ExciseTax
# SalesQuantity       1.000000      0.670142   -0.105416 -0.059658   0.528907
# SalesDollars        0.670142      1.000000    0.337337  0.129940   0.724628
# SalesPrice         -0.105416      0.337337    1.000000  0.229441   0.133121
# Volume             -0.059658      0.129940    0.229441  1.000000   0.258750
# ExciseTax           0.528907      0.724628    0.133121  0.258750   1.000000

# %%
## Correlation Heatmap
plt.figure(figsize=(8,6))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title("Correlation Matrix - Sales Dataset")

plt.show()

# %% [markdown]
# ## Correlation Analysis - Sales Dataset
# ## Observations
# ## 1. SalesQuantity and SalesDollars
# Correlation = 0.67
# This shows a moderately strong positive correlation.
# As the quantity sold increases, total sales revenue generally increases.
# ## 2. SalesDollars and ExciseTax
# Correlation = 0.72
# This is the strongest positive correlation in the dataset.
# Higher sales revenue results in higher excise tax, which is expected in business transactions.
# ## 3. SalesQuantity and ExciseTax
# Correlation = 0.53
# This indicates a moderate positive correlation.
# Selling more units generally increases the tax amount collected.
# ## 4. SalesPrice and SalesDollars
# Correlation = 0.34
# This indicates a weak to moderate positive correlation.
# Higher selling prices contribute to increased sales revenue, but quantity sold also influences the total revenue.
# ## 5. SalesPrice and SalesQuantity
# Correlation = -0.11
# This is a very weak negative correlation.
# The selling price has little influence on the quantity sold in this sample.
# ## 4. Volume and Other Variables
# Volume has only weak positive correlations with the other variables, indicating a limited direct relationship.

# %% [markdown]
# ## Business Logic Validation

# %%
# Negative Sales Quantity
print("Negative Sales Quantity:", (sales['SalesQuantity'] < 0).sum())
# Out:
# Negative Sales Quantity: 0

# %%
# Negative Sales Price
print("Negative Sales Price:", (sales['SalesPrice'] < 0).sum())
# Out:
# Negative Sales Price: 0

# %%
# Negative Sales Dollars
print("Negative Sales Dollars:", (sales['SalesDollars'] < 0).sum())
# Out:
# Negative Sales Dollars: 0

# %%
# Negative Excise Tax
print("Negative Excise Tax:", (sales['ExciseTax'] < 0).sum())
# Out:
# Negative Excise Tax: 0

# %% [markdown]
# ## Data Validation

# %%
# Convert SalesDate to datetime
sales['SalesDate'] = pd.to_datetime(sales['SalesDate'], errors='coerce')

# Check for invalid dates
print(sales['SalesDate'].isnull().sum())
# Out:
# 0

# %% [markdown]
# ## Observation
# * No negative values were found in Sales Quantity.
# * No negative values were found in Sales Price.
# * No negative values were found in Sales Dollars.
# * No negative values were found in Excise Tax.
# * SalesDate was successfully converted to datetime format without invalid or missing values.
# * The Sales dataset follows expected business rules and is suitable for further analysis.

# %% [markdown]
# ## Reliability Conclusion
#
# The Sales dataset successfully passed structural validation, data quality checks, correlation analysis, business logic validation, and date validation. The observed relationships among numerical variables are logically consistent with sales operations. Therefore, the dataset is considered reliable and suitable for further preprocessing and exploratory data analysis.

# %% [markdown]
# ## Purchase prices

# %%
purchase_prices.head()
# Out:
#    Brand                  Description  Price   Size Volume  Classification  \
# 0     58  Gekkeikan Black & Gold Sake  12.99  750mL    750               1
# 1     62     Herradura Silver Tequila  36.99  750mL    750               1
# 2     63   Herradura Reposado Tequila  38.99  750mL    750               1
# 3     72         No. 3 London Dry Gin  34.99  750mL    750               1
# 4     75    Three Olives Tomato Vodka  14.99  750mL    750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.28          8320  SHAW ROSS INT L IMP LTD
# 1          28.67          1128  BROWN-FORMAN CORP
# 2          30.46          1128  BROWN-FORMAN CORP
# 3          26.11          9165  ULTRA BEVERAGE COMPANY LLP
# 4          10.94          7245  PROXIMO SPIRITS INC.

# %%
purchase_prices.shape
# Out:
# (12261, 9)

# %%
purchase_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           12261 non-null  int64
#  1   Description     12260 non-null  object
#  2   Price           12261 non-null  float64
#  3   Size            12260 non-null  object
#  4   Volume          12260 non-null  object
#  5   Classification  12261 non-null  int64
#  6   PurchasePrice   12261 non-null  float64
#  7   VendorNumber    12261 non-null  int64
#  8   VendorName      12261 non-null  object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 862.2+ KB

# %%
purchase_prices.isnull().sum()
# Out:
# Brand             0
# Description       1
# Price             0
# Size              1
# Volume            1
# Classification    0
# PurchasePrice     0
# VendorNumber      0
# VendorName        0
# dtype: int64

# %%
# Fill missing Description
purchase_prices['Description'] = purchase_prices['Description'].fillna('Unknown')

# Fill missing Size
purchase_prices['Size'] = purchase_prices['Size'].fillna(purchase_prices['Size'].mode()[0])

# Fill missing Volume
purchase_prices['Volume'] = purchase_prices['Volume'].fillna(purchase_prices['Volume'].median())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 8
#       5 purchase_prices['Size'] = purchase_prices['Size'].fillna(purchase_prices['Size'].mode()[0])
#       7 # Fill missing Volume
# ----> 8 purchase_prices['Volume'] = purchase_prices['Volume'].fillna(purchase_prices['Volume'].median())
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:6559, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6551 @doc(make_doc("median", ndim=1))
#    6552 def median(
#    6553     self,
#    (...)
#    6557     **kwargs,
#    6558 ):
# -> 6559     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:12431, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12424 def median(
#   12425     self,
#   12426     axis: Axis | None = 0,
# ...

# %%
print(purchase_prices['Volume'].dtype)
# Out:
# object

# %%
purchase_prices.duplicated().sum()
# Out:
# 0

# %%
purchase_prices['Description'] = purchase_prices['Description'].fillna(
    purchase_prices['Description'].mode()[0]
)

# %%
purchase_prices['Size'] = purchase_prices['Size'].fillna(
    purchase_prices['Size'].mode()[0]
)

# %%
purchase_prices['Volume'] = purchase_prices['Volume'].fillna(
    purchase_prices['Volume'].mode()[0]
)

# %%
purchase_prices.isnull().sum()
# Out:
# Brand             0
# Description       0
# Price             0
# Size              0
# Volume            0
# Classification    0
# PurchasePrice     0
# VendorNumber      0
# VendorName        0
# dtype: int64

# %%
purchase_prices.duplicated().sum()
# Out:
# 0

# %%
purchase_prices.describe()
# Out:
#               Brand         Price  Classification  PurchasePrice  \
# count  12261.000000  12261.000000    12261.000000   12261.000000
# mean   17989.067123     38.640240        1.708996      26.488220
# std    12528.503464    206.151172        0.454244     156.182948
# min       58.000000      0.000000        1.000000       0.000000
# 25%     5990.000000     10.990000        1.000000       6.890000
# 50%    18788.000000     15.990000        2.000000      10.650000
# 75%    25117.000000     29.990000        2.000000      20.130000
# max    90631.000000  13999.900000        2.000000   11111.030000
#
#         VendorNumber
# count   12261.000000
# mean    10814.861757
# std     19007.682322
# min         2.000000
# 25%      3960.000000
# 50%      7153.000000
# 75%      9552.000000
# max    173357.000000

# %%
purchase_prices.nunique()
# Out:
# Brand             12261
# Description       11115
# Price               380
# Size                 56
# Volume               33
# Classification        2
# PurchasePrice      2314
# VendorNumber        131
# VendorName          136
# dtype: int64

# %%
numeric_columns = purchase_prices.select_dtypes(include=['number'])

print(numeric_columns.columns.tolist())
# Out:
# ['Brand', 'Price', 'Classification', 'PurchasePrice', 'VendorNumber']

# %%
corr_data = purchase_prices[['Price','PurchasePrice']]

corr_data.head()
# Out:
#    Price  PurchasePrice
# 0  12.99           9.28
# 1  36.99          28.67
# 2  38.99          30.46
# 3  34.99          26.11
# 4  14.99          10.94

# %%
correlation_matrix = corr_data.corr()

correlation_matrix
# Out:
#                   Price  PurchasePrice
# Price          1.000000       0.997658
# PurchasePrice  0.997658       1.000000

# %%
plt.figure(figsize=(5,4))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title("Correlation Matrix - Purchase Prices Dataset")

plt.show()

# %% [markdown]
# ## Correlation Analysis - Purchase Prices Dataset
# ### Observations
#
# 1. The correlation between **Price** and **PurchasePrice** is approximately **1.00**, indicating an extremely strong positive relationship.
#
# 2. As the Purchase Price increases, the Selling Price also increases proportionally.
#
# 3. This relationship is expected because selling prices are generally determined based on purchase costs along with the desired profit margin.
#
# 4. The strong positive correlation indicates that the pricing information in the dataset is consistent and logically related.
#
# ### Business Insight
#
# The Purchase Price dataset demonstrates a strong pricing relationship, suggesting that procurement costs directly influence product selling prices. This supports reliable pricing analysis and procurement decision-making.

# %%
## Business Logic Validation
print("Negative Purchase Price:",
      (purchase_prices['PurchasePrice'] < 0).sum())

print("Negative Selling Price:",
      (purchase_prices['Price'] < 0).sum())

print("Negative Vendor Number:",
      (purchase_prices['VendorNumber'] < 0).sum())
# Out:
# Negative Purchase Price: 0
# Negative Selling Price: 0
# Negative Vendor Number: 0

# %% [markdown]
# ## Business Logic Validation
#
# ### Observations
#
# - No negative values were found in PurchasePrice.
# - No negative values were found in Price.
# - VendorNumber contains valid positive identifiers.
# - The dataset follows expected procurement pricing business rules.

# %% [markdown]
# ## Reliability Conclusion
#
# The Purchase Prices dataset successfully passed structural validation, missing value assessment, duplicate checking, correlation analysis, and business logic validation. The strong positive relationship between PurchasePrice and Price confirms the consistency of the pricing information. Therefore, the dataset is reliable and suitable for procurement pricing analysis.

# %% [markdown]
# ## Vendor Invoice

# %%
vendor_invoice.head()
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2024-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2024-01-09      8169
# 3           480  BACARDI USA INC              2024-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2024-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval
# 0  2023-12-21  2024-02-16         6     214.26     3.47      NaN
# 1  2023-12-22  2024-02-21        15     140.55     8.57      NaN
# 2  2023-12-24  2024-02-16         5     106.60     4.61      NaN
# 3  2023-12-20  2024-02-05     10100  137483.78  2935.20      NaN
# 4  2023-12-24  2024-02-12      1935   15527.25   429.20      NaN

# %%
vendor_invoice.shape
# Out:
# (5543, 10)

# %%
vendor_invoice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5543 entries, 0 to 5542
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   VendorNumber  5543 non-null   int64
#  1   VendorName    5543 non-null   object
#  2   InvoiceDate   5543 non-null   object
#  3   PONumber      5543 non-null   int64
#  4   PODate        5543 non-null   object
#  5   PayDate       5543 non-null   object
#  6   Quantity      5543 non-null   int64
#  7   Dollars       5543 non-null   float64
#  8   Freight       5543 non-null   float64
#  9   Approval      374 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 433.2+ KB

# %%
vendor_invoice.isnull().sum()
# Out:
# VendorNumber       0
# VendorName         0
# InvoiceDate        0
# PONumber           0
# PODate             0
# PayDate            0
# Quantity           0
# Dollars            0
# Freight            0
# Approval        5169
# dtype: int64

# %%
vendor_invoice.duplicated().sum()
# Out:
# 0

# %%
vendor_invoice.describe()
# Out:
#        VendorNumber      PONumber       Quantity       Dollars      Freight
# count    5543.00000   5543.000000    5543.000000  5.543000e+03  5543.000000
# mean    20662.75212  10889.419087    6058.880931  5.807338e+04   295.954301
# std     34582.15841   1600.859969   14453.338164  1.402340e+05   713.585093
# min         2.00000   8106.000000       1.000000  4.140000e+00     0.020000
# 25%      3089.00000   9503.500000      83.000000  9.678100e+02     5.020000
# 50%      7240.00000  10890.000000     423.000000  4.765450e+03    24.730000
# 75%     10754.00000  12275.500000    5100.500000  4.458718e+04   229.660000
# max    201359.00000  13661.000000  141660.000000  1.660436e+06  8468.220000

# %%
vendor_invoice.nunique()
# Out:
# VendorNumber     126
# VendorName       129
# InvoiceDate      373
# PONumber        5543
# PODate           319
# PayDate          382
# Quantity        2895
# Dollars         5226
# Freight         4052
# Approval           1
# dtype: int64

# %%
numeric_columns = vendor_invoice.select_dtypes(include=['number'])

print("Numeric Columns:")
print(numeric_columns.columns.tolist())
# Out:
# Numeric Columns:
# ['VendorNumber', 'PONumber', 'Quantity', 'Dollars', 'Freight']

# %%
vendor_invoice['Approval'].value_counts(dropna=False)
# Out:
# Approval
# NaN               5169
# Frank Delahunt     374
# Name: count, dtype: int64

# %%
# Fill missing values in Approval with the most frequent value (mode)
vendor_invoice['Approval'] = vendor_invoice['Approval'].fillna(
    vendor_invoice['Approval'].mode()[0]
)

# %%
vendor_invoice.isnull().sum()
# Out:
# VendorNumber    0
# VendorName      0
# InvoiceDate     0
# PONumber        0
# PODate          0
# PayDate         0
# Quantity        0
# Dollars         0
# Freight         0
# Approval        0
# dtype: int64

# %%
corr_data = vendor_invoice[['Quantity', 'Dollars', 'Freight']]

corr_data.head()
# Out:
#    Quantity    Dollars  Freight
# 0         6     214.26     3.47
# 1        15     140.55     8.57
# 2         5     106.60     4.61
# 3     10100  137483.78  2935.20
# 4      1935   15527.25   429.20

# %%
## Calculate Correlation Matrix
correlation_matrix = corr_data.corr()

print(correlation_matrix)
# Out:
#           Quantity   Dollars   Freight
# Quantity  1.000000  0.963831  0.946550
# Dollars   0.963831  1.000000  0.985141
# Freight   0.946550  0.985141  1.000000

# %%
## Correlation Heatmap
plt.figure(figsize=(6,5))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title("Correlation Matrix - Vendor Invoice Dataset")

plt.show()

# %% [markdown]
# ## Correlation Analysis - Vendor Invoice Dataset
#
# ### Observations
#
# 1. Quantity shows a positive correlation with Dollars, indicating that larger purchase quantities generally result in higher invoice amounts.
#
# 2. Freight has a positive relationship with Dollars, suggesting that transportation costs increase as invoice values increase.
#
# 3. Quantity and Freight also exhibit a positive relationship, as larger orders generally require higher transportation costs.
#
# 4. The correlation values indicate logical business relationships among procurement quantity, invoice amount, and freight charges.
#
# ### Business Insight
#
# The Vendor Invoice dataset demonstrates meaningful relationships between purchasing quantity, invoice amount, and freight cost. These relationships support procurement cost analysis and vendor performance evaluation.

# %% [markdown]
# ## Business Logic Validation

# %%
print("Negative Quantity:",
      (vendor_invoice['Quantity'] < 0).sum())

print("Negative Dollars:",
      (vendor_invoice['Dollars'] < 0).sum())

print("Negative Freight:",
      (vendor_invoice['Freight'] < 0).sum())
# Out:
# Negative Quantity: 0
# Negative Dollars: 0
# Negative Freight: 0

# %%
## Date Validation


vendor_invoice['InvoiceDate'] = pd.to_datetime(
    vendor_invoice['InvoiceDate'],
    errors='coerce'
)

vendor_invoice['PODate'] = pd.to_datetime(
    vendor_invoice['PODate'],
    errors='coerce'
)

vendor_invoice['PayDate'] = pd.to_datetime(
    vendor_invoice['PayDate'],
    errors='coerce'
)

# %%
vendor_invoice[['InvoiceDate','PODate','PayDate']].isnull().sum()
# Out:
# InvoiceDate    0
# PODate         0
# PayDate        0
# dtype: int64

# %% [markdown]
# ## Business Logic Validation
#
# ### Observations
#
# - Quantity contains no negative values.
# - Dollars contains no negative values.
# - Freight contains no negative values.
# - InvoiceDate, PODate, and PayDate were successfully converted to datetime format without invalid values.
# - Vendor Invoice data follows expected procurement and financial business rules.

# %% [markdown]
# ## Reliability Conclusion
#
# The Vendor Invoice dataset successfully passed structural validation, missing value handling, duplicate checking, summary statistics, correlation analysis, business rule validation, and date validation. The dataset is reliable and suitable for vendor invoice analysis, procurement cost monitoring, and vendor performance evaluation.

# %% [markdown]
# ## Vendor Sales Summary

# %%
vendor_sales_summary.head()
# Out:
#    VendorNumber                VendorName  Brand              Description  \
# 0          1128         BROWN-FORMAN CORP   1233  Jack Daniels No 7 Black
# 1          4425     MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035         PERNOD RICARD USA   8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC   4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC   3545          Ketel One Vodka
#
#    PurchasePrice  ActualPrice  Volume  TotalPurchaseQuantity  \
# 0          26.27        36.99  1750.0                 145080
# 1          23.19        28.99  1750.0                 164038
# 2          18.24        24.99  1750.0                 187407
# 3          16.17        22.99  1750.0                 201682
# 4          21.89        29.99  1750.0                 138109
#
#    TotalPurchaseDollars  TotalSalesQuantity  TotalSalesPrice  \
# 0            3811251.60            142049.0        672819.31
# ...

# %%
vendor_sales_summary.shape
# Out:
# (10692, 18)

# %%
vendor_sales_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10692 entries, 0 to 10691
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorNumber           10692 non-null  int64
#  1   VendorName             10692 non-null  object
#  2   Brand                  10692 non-null  int64
#  3   Description            10692 non-null  object
#  4   PurchasePrice          10692 non-null  float64
#  5   ActualPrice            10692 non-null  float64
#  6   Volume                 10692 non-null  float64
#  7   TotalPurchaseQuantity  10692 non-null  int64
#  8   TotalPurchaseDollars   10692 non-null  float64
#  9   TotalSalesQuantity     10692 non-null  float64
#  10  TotalSalesPrice        10692 non-null  float64
#  11  TotalSalesDollars      10692 non-null  float64
#  12  TotalExciseTax         10692 non-null  float64
#  13  FreightCost            10692 non-null  float64
# ...

# %%
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber             0
# VendorName               0
# Brand                    0
# Description              0
# PurchasePrice            0
# ActualPrice              0
# Volume                   0
# TotalPurchaseQuantity    0
# TotalPurchaseDollars     0
# TotalSalesQuantity       0
# TotalSalesPrice          0
# TotalSalesDollars        0
# TotalExciseTax           0
# FreightCost              0
# GrossProfit              0
# ProfitMargin             0
# StockTurnover            0
# SalestoPurchaseRatio     0
# dtype: int64

# %%
vendor_sales_summary.duplicated().sum()
# Out:
# 0

# %%
vendor_sales_summary.describe()
# Out:
#         VendorNumber         Brand  PurchasePrice   ActualPrice        Volume  \
# count   10692.000000  10692.000000   10692.000000  10692.000000  10692.000000
# mean    10650.649458  18039.228769      24.385303     35.643671    847.360550
# std     18753.519148  12662.187074     109.269375    148.246016    664.309212
# min         2.000000     58.000000       0.360000      0.490000     50.000000
# 25%      3951.000000   5793.500000       6.840000     10.990000    750.000000
# 50%      7153.000000  18761.500000      10.455000     15.990000    750.000000
# 75%      9552.000000  25514.250000      19.482500     28.990000    750.000000
# max    201359.000000  90631.000000    5681.810000   7499.990000  20000.000000
#
#        TotalPurchaseQuantity  TotalPurchaseDollars  TotalSalesQuantity  \
# count           10692.000000          1.069200e+04        10692.000000
# mean             3140.886831          3.010669e+04         3077.482136
# ...

# %%
vendor_sales_summary.nunique()
# Out:
# VendorNumber               126
# VendorName                 128
# Brand                    10663
# Description               9651
# PurchasePrice             2150
# ActualPrice                342
# Volume                      31
# TotalPurchaseQuantity     3876
# TotalPurchaseDollars      9779
# TotalSalesQuantity        3809
# TotalSalesPrice           8835
# TotalSalesDollars         9390
# TotalExciseTax            7254
# FreightCost                126
# GrossProfit              10567
# ProfitMargin             10320
# StockTurnover             7308
# SalestoPurchaseRatio     10310
# dtype: int64

# %%
numeric_columns = vendor_sales_summary.select_dtypes(include=['number'])

print("Numeric Columns:")
print(numeric_columns.columns.tolist())
# Out:
# Numeric Columns:
# ['VendorNumber', 'Brand', 'PurchasePrice', 'ActualPrice', 'Volume', 'TotalPurchaseQuantity', 'TotalPurchaseDollars', 'TotalSalesQuantity', 'TotalSalesPrice', 'TotalSalesDollars', 'TotalExciseTax', 'FreightCost', 'GrossProfit', 'ProfitMargin', 'StockTurnover', 'SalestoPurchaseRatio']

# %%
## Continuous Numerical Variables

continuous_variables = [
    'PurchasePrice',
    'ActualPrice',
    'Volume',
    'TotalPurchaseQuantity',
    'TotalPurchaseDollars',
    'TotalSalesQuantity',
    'TotalSalesPrice',
    'TotalSalesDollars',
    'TotalExciseTax',
    'FreightCost',
    'GrossProfit',
    'ProfitMargin',
    'StockTurnover',
    'SalestoPurchaseRatio'
]

print("Continuous Numerical Variables:")
print(continuous_variables)
# Out:
# Continuous Numerical Variables:
# ['PurchasePrice', 'ActualPrice', 'Volume', 'TotalPurchaseQuantity', 'TotalPurchaseDollars', 'TotalSalesQuantity', 'TotalSalesPrice', 'TotalSalesDollars', 'TotalExciseTax', 'FreightCost', 'GrossProfit', 'ProfitMargin', 'StockTurnover', 'SalestoPurchaseRatio']

# %%
## Correlation Dataset
corr_data = vendor_sales_summary[continuous_variables]

corr_data.head()
# Out:
#    PurchasePrice  ActualPrice  Volume  TotalPurchaseQuantity  \
# 0          26.27        36.99  1750.0                 145080
# 1          23.19        28.99  1750.0                 164038
# 2          18.24        24.99  1750.0                 187407
# 3          16.17        22.99  1750.0                 201682
# 4          21.89        29.99  1750.0                 138109
#
#    TotalPurchaseDollars  TotalSalesQuantity  TotalSalesPrice  \
# 0            3811251.60            142049.0        672819.31
# 1            3804041.22            160247.0        561512.37
# 2            3418303.68            187140.0        461140.15
# 3            3261197.94            200412.0        420050.01
# 4            3023206.01            135838.0        545778.28
#
#    TotalSalesDollars  TotalExciseTax  FreightCost  GrossProfit  ProfitMargin  \
# 0         5101919.51       260999.20     68601.68   1290667.91     25.297693
# ...

# %%
## Correlation Matrix
correlation_matrix = corr_data.corr()

print(correlation_matrix)
# Out:
#                        PurchasePrice  ActualPrice    Volume  \
# PurchasePrice               1.000000     0.997197  0.019713
# ActualPrice                 0.997197     1.000000  0.022845
# Volume                      0.019713     0.022845  1.000000
# TotalPurchaseQuantity      -0.038346    -0.041480  0.012899
# TotalPurchaseDollars       -0.009977    -0.012424  0.098102
# TotalSalesQuantity         -0.038236    -0.041330  0.014210
# TotalSalesPrice            -0.012790    -0.016527  0.140049
# TotalSalesDollars          -0.013445    -0.015643  0.100966
# TotalExciseTax             -0.014502    -0.016806  0.131636
# FreightCost                 0.023795     0.021340 -0.013535
# GrossProfit                -0.022204    -0.023657  0.105013
# ProfitMargin               -0.013929    -0.013656  0.016469
# StockTurnover              -0.004003    -0.003325 -0.031959
# SalestoPurchaseRatio       -0.005086    -0.004084 -0.031336
#
# ...

# %%
## Correlation Heatmap
plt.figure(figsize=(14,10))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title("Correlation Matrix - Vendor Sales Summary")

plt.show()

# %% [markdown]
# ## Correlation Analysis - Vendor Sales Summary
#
# ### Observations
#
# 1. PurchasePrice and ActualPrice show a perfect positive correlation (1.00), indicating that both variables contain nearly identical pricing information.
#
# 2. TotalPurchaseDollars and TotalSalesDollars have a very strong positive correlation (approximately 1.00), showing that vendors with higher purchase values also generate higher sales revenue.
#
# 3. GrossProfit has a very strong positive correlation with TotalSalesDollars and TotalPurchaseDollars, indicating that higher sales and purchase values contribute to greater profit.
#
# 4. TotalPurchaseQuantity and TotalSalesQuantity have a strong positive relationship, suggesting that products purchased in larger quantities are generally sold in larger quantities.
#
# 5. FreightCost has a weak positive correlation with most variables, indicating that transportation cost has a relatively smaller impact on overall vendor performance.
#
# 6. ProfitMargin, StockTurnover, and SalestoPurchaseRatio have weak correlations with most financial variables because they are efficiency ratios rather than direct monetary values.
#
# ### Business Insight
#
# The Vendor Sales Summary dataset demonstrates strong relationships between purchasing, sales, and profitability. These insights help evaluate vendor performance, monitor procurement efficiency, and identify high-performing vendors.

# %%
## Step 15 : Business Logic Validation
print("Negative PurchasePrice:",
      (vendor_sales_summary['PurchasePrice'] < 0).sum())

print("Negative ActualPrice:",
      (vendor_sales_summary['ActualPrice'] < 0).sum())

print("Negative TotalPurchaseQuantity:",
      (vendor_sales_summary['TotalPurchaseQuantity'] < 0).sum())

print("Negative TotalSalesQuantity:",
      (vendor_sales_summary['TotalSalesQuantity'] < 0).sum())

print("Negative GrossProfit:",
      (vendor_sales_summary['GrossProfit'] < 0).sum())
# Out:
# Negative PurchasePrice: 0
# Negative ActualPrice: 0
# Negative TotalPurchaseQuantity: 0
# Negative TotalSalesQuantity: 0
# Negative GrossProfit: 2127

# %% [markdown]
# ## Date Validation
#
# No date columns are present in the Vendor Sales Summary dataset. Therefore, date validation is not applicable.

# %% [markdown]
# ## Reliability Conclusion
#
# The Vendor Sales Summary dataset successfully passed data validation, duplicate checking, summary statistics, correlation analysis, and business logic validation.
#
# No missing values were found in the dataset, and no date columns were available for validation.
#
# The dataset is reliable and suitable for vendor performance analysis, procurement analysis, profitability analysis, and business intelligence reporting.

# %% [markdown]
# ## Begin Inventory

# %%
begin_inventory.head()
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01

# %%
begin_inventory.shape
# Out:
# (206529, 9)

# %%
begin_inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206529 entries, 0 to 206528
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InventoryId  206529 non-null  object
#  1   Store        206529 non-null  int64
#  2   City         206529 non-null  object
#  3   Brand        206529 non-null  int64
#  4   Description  206529 non-null  object
#  5   Size         206529 non-null  object
#  6   onHand       206529 non-null  int64
#  7   Price        206529 non-null  float64
#  8   startDate    206529 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 14.2+ MB

# %%
begin_inventory.isnull().sum()
# Out:
# InventoryId    0
# Store          0
# City           0
# Brand          0
# Description    0
# Size           0
# onHand         0
# Price          0
# startDate      0
# dtype: int64

# %%
begin_inventory.duplicated().sum()
# Out:
# 0

# %%
begin_inventory.describe()
# Out:
#                Store          Brand         onHand          Price
# count  206529.000000  206529.000000  206529.000000  206529.000000
# mean       42.122457   13761.482320      20.429455      22.253910
# std        23.191393   13059.429355      31.467342      70.178964
# min         1.000000      58.000000       0.000000       0.000000
# 25%        22.000000    3746.000000       7.000000       9.990000
# 50%        42.000000    8010.000000      12.000000      14.990000
# 75%        64.000000   22143.000000      21.000000      21.990000
# max        79.000000   90090.000000    1251.000000   13999.900000

# %%
begin_inventory.nunique()
# Out:
# InventoryId    206529
# Store              79
# City               67
# Brand            8094
# Description      7291
# Size               41
# onHand            474
# Price             329
# startDate           1
# dtype: int64

# %%
numeric_columns = begin_inventory.select_dtypes(include=['number'])

print("Numeric Columns:")
print(numeric_columns.columns.tolist())
# Out:
# Numeric Columns:
# ['Store', 'Brand', 'onHand', 'Price']

# %%
## Continuous Numerical Variables
continuous_variables = [
    'onHand',
    'Price'
]

print("Continuous Numerical Variables:")
print(continuous_variables)
# Out:
# Continuous Numerical Variables:
# ['onHand', 'Price']

# %%
## Correlation Dataset
corr_data = begin_inventory[continuous_variables]

corr_data.head()
# Out:
#    onHand  Price
# 0       8  12.99
# 1       7  10.99
# 2       6  36.99
# 3       3  38.99
# 4       6  34.99

# %%
## Correlation Matrix
correlation_matrix = corr_data.corr()

print(correlation_matrix)
# Out:
#          onHand    Price
# onHand  1.00000 -0.05666
# Price  -0.05666  1.00000

# %%
## Correlation Heatmap
plt.figure(figsize=(5,4))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title("Correlation Matrix - Begin Inventory Dataset")

plt.show()

# %% [markdown]
# ## Correlation Analysis - Begin Inventory Dataset
#
# ### Observations
#
# 1. The correlation between **onHand** and **Price** is **-0.06**, indicating a very weak negative relationship.
#
# 2. Inventory quantity does not significantly influence product price.
#
# 3. The weak correlation suggests that inventory levels and pricing are managed independently.
#
# 4. No strong linear relationship exists between stock quantity and product price in the Begin Inventory dataset.
#
# ### Business Insight
#
# The Begin Inventory dataset indicates that stock availability is not directly related to product pricing. Inventory decisions are likely influenced by demand, replenishment strategy, and operational planning rather than price alone.

# %%
## Business Logic Validation
print("Negative onHand:",
      (begin_inventory['onHand'] < 0).sum())

print("Negative Price:",
      (begin_inventory['Price'] < 0).sum())
# Out:
# Negative onHand: 0
# Negative Price: 0

# %%
## Date Validation
begin_inventory['startDate'] = pd.to_datetime(
    begin_inventory['startDate'],
    errors='coerce'
)

# %%
begin_inventory[['startDate']].isnull().sum()
# Out:
# startDate    0
# dtype: int64

# %% [markdown]
# ## Reliability Conclusion
#
# The Begin Inventory dataset successfully passed data validation, duplicate checking, missing value assessment, correlation analysis, business logic validation, and date validation.
#
# No missing values or invalid dates were found. The dataset is reliable and suitable for inventory management, stock availability analysis, and procurement planning.

# %% [markdown]
# ## End Inventory

# %%
end_inventory.head()
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 2  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 3  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
# 4  1_HARDERSFIELD_75      1  HARDERSFIELD     75    Three Olives Tomato Vodka
#
#     Size  onHand  Price     endDate
# 0  750mL      11  12.99  2024-12-31
# 1  750mL       7  36.99  2024-12-31
# 2  750mL       7  38.99  2024-12-31
# 3  750mL       4  34.99  2024-12-31
# 4  750mL       7  14.99  2024-12-31

# %%
end_inventory.shape
# Out:
# (224489, 9)

# %%
end_inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224489 entries, 0 to 224488
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InventoryId  224489 non-null  object
#  1   Store        224489 non-null  int64
#  2   City         223205 non-null  object
#  3   Brand        224489 non-null  int64
#  4   Description  224489 non-null  object
#  5   Size         224489 non-null  object
#  6   onHand       224489 non-null  int64
#  7   Price        224489 non-null  float64
#  8   endDate      224489 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 15.4+ MB

# %%
end_inventory.isnull().sum()
# Out:
# InventoryId       0
# Store             0
# City           1284
# Brand             0
# Description       0
# Size              0
# onHand            0
# Price             0
# endDate           0
# dtype: int64

# %%
# Fill missing values in City with the most frequent city
end_inventory['City'] = end_inventory['City'].fillna(
    end_inventory['City'].mode()[0]
)

# %%
end_inventory.isnull().sum()
# Out:
# InventoryId    0
# Store          0
# City           0
# Brand          0
# Description    0
# Size           0
# onHand         0
# Price          0
# endDate        0
# dtype: int64

# %%
end_inventory.duplicated().sum()
# Out:
# 0

# %%
end_inventory.describe()
# Out:
#                Store          Brand         onHand          Price
# count  224489.000000  224489.000000  224489.000000  224489.000000
# mean       43.505740   14356.370513      21.763988      23.585583
# std        23.326415   13118.467851      37.233576      79.202775
# min         1.000000      58.000000       0.000000       0.490000
# 25%        23.000000    3798.000000       7.000000       9.990000
# 50%        44.000000    8259.000000      12.000000      14.990000
# 75%        66.000000   23965.000000      22.000000      23.490000
# max        81.000000   90631.000000    3676.000000   13999.900000

# %%
end_inventory.nunique()
# Out:
# InventoryId    224489
# Store              80
# City               67
# Brand            9653
# Description      8732
# Size               47
# onHand            548
# Price             354
# endDate             1
# dtype: int64

# %%
numeric_columns = end_inventory.select_dtypes(include=['number'])

print("Numeric Columns:")
print(numeric_columns.columns.tolist())
# Out:
# Numeric Columns:
# ['Store', 'Brand', 'onHand', 'Price']

# %%
## Continuous Numerical Variables
continuous_variables = [
    'onHand',
    'Price'
]

print("Continuous Numerical Variables:")
print(continuous_variables)
# Out:
# Continuous Numerical Variables:
# ['onHand', 'Price']

# %%
## Correlation Dataset
corr_data = end_inventory[continuous_variables]

corr_data.head()
# Out:
#    onHand  Price
# 0      11  12.99
# 1       7  36.99
# 2       7  38.99
# 3       4  34.99
# 4       7  14.99

# %%
## Correlation Matrix
correlation_matrix = corr_data.corr()

print(correlation_matrix)
# Out:
#           onHand     Price
# onHand  1.000000 -0.053668
# Price  -0.053668  1.000000

# %%
## Correlation Heatmap
plt.figure(figsize=(5,4))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title("Correlation Matrix - End Inventory Dataset")

plt.show()

# %% [markdown]
# ## Correlation Analysis - End Inventory Dataset
#
# ### Observations
#
# 1. The correlation between **onHand** and **Price** is **-0.05**, indicating a very weak negative relationship.
#
# 2. Product price has minimal influence on the remaining inventory quantity.
#
# 3. The weak correlation suggests that end inventory levels are managed independently of product pricing.
#
# 4. No strong linear relationship exists between stock quantity and price in the End Inventory dataset.
#
# ### Business Insight
#
# The End Inventory dataset indicates that inventory remaining at the end of the period is not directly driven by product price. Inventory levels are more likely influenced by customer demand, sales performance, and replenishment strategies.

# %%
## Business Logic Validation
print("Negative onHand:",
      (end_inventory['onHand'] < 0).sum())

print("Negative Price:",
      (end_inventory['Price'] < 0).sum())
# Out:
# Negative onHand: 0
# Negative Price: 0

# %%
## Date Validation
end_inventory['endDate'] = pd.to_datetime(
    end_inventory['endDate'],
    errors='coerce'
)

# %%
end_inventory[['endDate']].isnull().sum()
# Out:
# endDate    0
# dtype: int64

# %% [markdown]
# ## Reliability Conclusion
#
# The End Inventory dataset successfully passed data validation, duplicate checking, missing value handling, correlation analysis, business logic validation, and date validation.
#
# The missing values in the **City** column were handled using mode imputation. No invalid dates or negative inventory values were found. The dataset is reliable and suitable for inventory tracking, stock availability analysis, and procurement decision-making.

# %% [markdown]
# ## Purchase orders

# %%
purchase_orders.head()
# Out:
#       po_id supplier_id site_id part_id  order_date promised_date  \
# 0  PO000001      SUP004  SITE01  P00001  2022-05-02    2022-05-28
# 1  PO000002      SUP004  SITE01  P00001  2022-07-04    2022-07-31
# 2  PO000003      SUP004  SITE01  P00001  2022-10-17    2022-11-12
# 3  PO000004      SUP004  SITE01  P00001  2023-02-06    2023-03-07
# 4  PO000005      SUP004  SITE01  P00001  2023-04-03    2023-04-28
#
#   receipt_date  ordered_qty  received_qty
# 0   2022-05-29           16            16
# 1   2022-08-02            5             5
# 2   2022-11-16            5             5
# 3   2023-03-09            3             3
# 4   2023-04-29            5             5

# %%
purchase_orders.shape
# Out:
# (29666, 9)

# %%
purchase_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29666 entries, 0 to 29665
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   po_id          29666 non-null  object
#  1   supplier_id    29666 non-null  object
#  2   site_id        29666 non-null  object
#  3   part_id        29666 non-null  object
#  4   order_date     29666 non-null  object
#  5   promised_date  29666 non-null  object
#  6   receipt_date   29666 non-null  object
#  7   ordered_qty    29666 non-null  int64
#  8   received_qty   29666 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 2.0+ MB

# %%
purchase_orders.isnull().sum()
# Out:
# po_id            0
# supplier_id      0
# site_id          0
# part_id          0
# order_date       0
# promised_date    0
# receipt_date     0
# ordered_qty      0
# received_qty     0
# dtype: int64

# %%
purchase_orders.duplicated().sum()
# Out:
# 0

# %%
purchase_orders.describe()
# Out:
#         ordered_qty  received_qty
# count  29666.000000  29666.000000
# mean      14.653105     14.236399
# std       13.862931     13.534927
# min        1.000000      1.000000
# 25%        6.000000      6.000000
# 50%       11.000000     10.000000
# 75%       19.000000     18.000000
# max      263.000000    263.000000

# %%
purchase_orders.nunique()
# Out:
# po_id            29666
# supplier_id         40
# site_id              6
# part_id            300
# order_date         156
# promised_date     1159
# receipt_date      1162
# ordered_qty        140
# received_qty       139
# dtype: int64

# %%
numeric_columns = purchase_orders.select_dtypes(include=['number'])

print("Numeric Columns:")
print(numeric_columns.columns.tolist())
# Out:
# Numeric Columns:
# ['ordered_qty', 'received_qty']

# %%
## Continuous Numerical Variables
continuous_variables = [
    'ordered_qty',
    'received_qty'
]

print("Continuous Numerical Variables:")
print(continuous_variables)
# Out:
# Continuous Numerical Variables:
# ['ordered_qty', 'received_qty']

# %%
## Correlation Dataset
corr_data = purchase_orders[continuous_variables]

corr_data.head()
# Out:
#    ordered_qty  received_qty
# 0           16            16
# 1            5             5
# 2            5             5
# 3            3             3
# 4            5             5

# %%
## Correlation Matrix
correlation_matrix = corr_data.corr()

print(correlation_matrix)
# Out:
#               ordered_qty  received_qty
# ordered_qty       1.00000       0.99196
# received_qty      0.99196       1.00000

# %%
## Correlation Heatmap
plt.figure(figsize=(5,4))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title("Correlation Matrix - Purchase Orders Dataset")

plt.show()

# %% [markdown]
# ## Correlation Analysis - Purchase Orders Dataset
#
# ### Observations
#
# 1. The correlation between **ordered_qty** and **received_qty** is **0.99**, indicating a very strong positive relationship.
#
# 2. Suppliers generally deliver quantities very close to the quantities ordered.
#
# 3. The strong positive correlation reflects high procurement accuracy and efficient order fulfillment.
#
# 4. Very few discrepancies exist between ordered and received quantities.
#
# ### Business Insight
#
# The Purchase Orders dataset demonstrates excellent supplier delivery performance. The strong relationship between ordered and received quantities indicates a reliable procurement process with minimal quantity deviations.

# %%
## Business Logic Validation

print("Negative Ordered Quantity:",
      (purchase_orders['ordered_qty'] < 0).sum())

print("Negative Received Quantity:",
      (purchase_orders['received_qty'] < 0).sum())

print("Received Quantity greater than Ordered Quantity:",
      (purchase_orders['received_qty'] > purchase_orders['ordered_qty']).sum())
# Out:
# Negative Ordered Quantity: 0
# Negative Received Quantity: 0
# Received Quantity greater than Ordered Quantity: 0

# %%
##  Date Validation
date_columns = [
    'order_date',
    'promised_date',
    'receipt_date'
]

for col in date_columns:
    purchase_orders[col] = pd.to_datetime(
        purchase_orders[col],
        errors='coerce'
    )

# %%
purchase_orders[date_columns].isnull().sum()
# Out:
# order_date       0
# promised_date    0
# receipt_date     0
# dtype: int64

# %% [markdown]
# ## Reliability Conclusion
#
# The Purchase Orders dataset successfully passed data validation, duplicate checking, missing value assessment, correlation analysis, business logic validation, and date validation.
#
# No missing values, invalid dates, or negative quantities were identified. The strong correlation between ordered and received quantities indicates a reliable procurement process. This dataset is suitable for procurement performance analysis, supplier evaluation, and purchase order tracking.

# %% [markdown]
# ## Procurement KPI Analysis Dataset

# %%
Procurement_KPI_Analysis_Dataset.head()
# Out:
#       PO_ID         Supplier  Order_Date Delivery_Date    Item_Category  \
# 0  PO-00001        Alpha_Inc  2023-10-17    2023-10-25  Office Supplies
# 1  PO-00002  Delta_Logistics  2022-04-25    2022-05-05  Office Supplies
# 2  PO-00003         Gamma_Co  2022-01-26    2022-02-15              MRO
# 3  PO-00004    Beta_Supplies  2022-10-09    2022-10-28        Packaging
# 4  PO-00005  Delta_Logistics  2022-09-08    2022-09-20    Raw Materials
#
#   Order_Status  Quantity  Unit_Price  Negotiated_Price  Defective_Units  \
# 0    Cancelled      1176       20.13             17.81              NaN
# 1    Delivered      1509       39.32             37.34            235.0
# 2    Delivered       910       95.51             92.26             41.0
# 3    Delivered      1344       99.85             95.52            112.0
# 4    Delivered      1180       64.07             60.53            171.0
#
#   Compliance
# 0        Yes
# 1        Yes
# 2        Yes
# 3        Yes
# 4         No

# %%
Procurement_KPI_Analysis_Dataset.shape
# Out:
# (777, 11)

# %%
Procurement_KPI_Analysis_Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PO_ID             777 non-null    object
#  1   Supplier          777 non-null    object
#  2   Order_Date        777 non-null    object
#  3   Delivery_Date     690 non-null    object
#  4   Item_Category     777 non-null    object
#  5   Order_Status      777 non-null    object
#  6   Quantity          777 non-null    int64
#  7   Unit_Price        777 non-null    float64
#  8   Negotiated_Price  777 non-null    float64
#  9   Defective_Units   641 non-null    float64
#  10  Compliance        777 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 66.9+ KB

# %%
Procurement_KPI_Analysis_Dataset.isnull().sum()
# Out:
# PO_ID                 0
# Supplier              0
# Order_Date            0
# Delivery_Date        87
# Item_Category         0
# Order_Status          0
# Quantity              0
# Unit_Price            0
# Negotiated_Price      0
# Defective_Units     136
# Compliance            0
# dtype: int64

# %%
# Fill missing values in Defective_Units

Procurement_KPI_Analysis_Dataset['Defective_Units'] = Procurement_KPI_Analysis_Dataset['Defective_Units'].fillna(
    Procurement_KPI_Analysis_Dataset['Defective_Units'].median()
)

# %%
print(Procurement_KPI_Analysis_Dataset['Delivery_Date'].dtype)
# Out:
# object

# %%
Procurement_KPI_Analysis_Dataset['Delivery_Date'] = Procurement_KPI_Analysis_Dataset['Delivery_Date'].fillna(
    Procurement_KPI_Analysis_Dataset['Delivery_Date'].mode()[0]
)

# %%
Procurement_KPI_Analysis_Dataset.isnull().sum()
# Out:
# PO_ID               0
# Supplier            0
# Order_Date          0
# Delivery_Date       0
# Item_Category       0
# Order_Status        0
# Quantity            0
# Unit_Price          0
# Negotiated_Price    0
# Defective_Units     0
# Compliance          0
# dtype: int64

# %%
Procurement_KPI_Analysis_Dataset.duplicated().sum()
# Out:
# 0

# %%
Procurement_KPI_Analysis_Dataset.describe()
# Out:
#           Quantity  Unit_Price  Negotiated_Price  Defective_Units
# count   777.000000  777.000000        777.000000       777.000000
# mean   1094.660232   58.283822         53.660721        70.287001
# std     647.844551   28.101315         26.094930        63.594610
# min      51.000000   10.840000          9.270000         0.000000
# 25%     615.000000   33.290000         30.460000        29.000000
# 50%    1075.000000   58.950000         53.800000        49.000000
# 75%    1548.000000   83.130000         76.550000        85.000000
# max    5000.000000  109.170000        107.390000       321.000000

# %%
Procurement_KPI_Analysis_Dataset.nunique()
# Out:
# PO_ID               777
# Supplier              5
# Order_Date          476
# Delivery_Date       449
# Item_Category         5
# Order_Status          4
# Quantity            623
# Unit_Price          747
# Negotiated_Price    752
# Defective_Units     202
# Compliance            2
# dtype: int64

# %%
numeric_columns = Procurement_KPI_Analysis_Dataset.select_dtypes(include=['number'])

print("Numeric Columns:")
print(numeric_columns.columns.tolist())
# Out:
# Numeric Columns:
# ['Quantity', 'Unit_Price', 'Negotiated_Price', 'Defective_Units']

# %%
## Continuous Numerical Variables 
continuous_variables = [
    'Quantity',
    'Unit_Price',
    'Negotiated_Price',
    'Defective_Units'
]

print("Continuous Numerical Variables:")
print(continuous_variables)
# Out:
# Continuous Numerical Variables:
# ['Quantity', 'Unit_Price', 'Negotiated_Price', 'Defective_Units']

# %%
## Correlation Dataset

corr_data = Procurement_KPI_Analysis_Dataset[continuous_variables]

corr_data.head()
# Out:
#    Quantity  Unit_Price  Negotiated_Price  Defective_Units
# 0      1176       20.13             17.81             49.0
# 1      1509       39.32             37.34            235.0
# 2       910       95.51             92.26             41.0
# 3      1344       99.85             95.52            112.0
# 4      1180       64.07             60.53            171.0

# %%
## Correlation Matix
correlation_matrix = corr_data.corr()

print(correlation_matrix)
# Out:
#                   Quantity  Unit_Price  Negotiated_Price  Defective_Units
# Quantity          1.000000   -0.019009         -0.020390         0.406213
# Unit_Price       -0.019009    1.000000          0.994602        -0.015489
# Negotiated_Price -0.020390    0.994602          1.000000        -0.014950
# Defective_Units   0.406213   -0.015489         -0.014950         1.000000

# %%
## Correlation Heatmap
plt.figure(figsize=(7,5))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title("Correlation Matrix - Procurement KPI Dataset")

plt.show()

# %% [markdown]
# ## Correlation Analysis - Procurement KPI Dataset
#
# ### Observations
#
# 1. **Unit_Price** and **Negotiated_Price** have a **very strong positive correlation (0.99)**, indicating that negotiated prices are very close to the original unit prices.
#
# 2. **Quantity** and **Defective_Units** show a **moderate positive correlation (0.41)**, suggesting that as order quantity increases, the number of defective units tends to increase slightly.
#
# 3. **Quantity** has almost no correlation with **Unit_Price** and **Negotiated_Price**.
#
# 4. **Defective_Units** has almost no relationship with pricing variables.
#
# ### Business Insight
#
# The procurement process maintains pricing consistency, while defect counts are more influenced by order volume than by product pricing. This indicates stable supplier pricing but highlights the need to monitor quality when purchasing larger quantities.

# %%
## Business Logic Validation
print("Negative Quantity:",
      (Procurement_KPI_Analysis_Dataset['Quantity'] < 0).sum())

print("Negative Unit Price:",
      (Procurement_KPI_Analysis_Dataset['Unit_Price'] < 0).sum())

print("Negative Negotiated Price:",
      (Procurement_KPI_Analysis_Dataset['Negotiated_Price'] < 0).sum())

print("Negative Defective Units:",
      (Procurement_KPI_Analysis_Dataset['Defective_Units'] < 0).sum())

print("Negotiated Price greater than Unit Price:",
      (Procurement_KPI_Analysis_Dataset['Negotiated_Price'] > Procurement_KPI_Analysis_Dataset['Unit_Price']).sum())

print("Defective Units greater than Quantity:",
      (Procurement_KPI_Analysis_Dataset['Defective_Units'] > Procurement_KPI_Analysis_Dataset['Quantity']).sum())
# Out:
# Negative Quantity: 0
# Negative Unit Price: 0
# Negative Negotiated Price: 0
# Negative Defective Units: 0
# Negotiated Price greater than Unit Price: 0
# Defective Units greater than Quantity: 0

# %%
## Data Validation
date_columns = [
    'Order_Date',
    'Delivery_Date'
]

for col in date_columns:
    Procurement_KPI_Analysis_Dataset[col] = pd.to_datetime(
        Procurement_KPI_Analysis_Dataset[col],
        errors='coerce'
    )

# %%
Procurement_KPI_Analysis_Dataset[date_columns].isnull().sum()
# Out:
# Order_Date       0
# Delivery_Date    0
# dtype: int64

# %% [markdown]
# ## Reliability Conclusion
#
# The Procurement KPI dataset successfully passed data validation, duplicate checking, missing value handling, correlation analysis, business logic validation, and date validation.
#
# Missing values in **Delivery_Date** and **Defective_Units** were handled appropriately. The dataset shows strong pricing consistency between Unit Price and Negotiated Price, and all key business rules were validated. This dataset is reliable for procurement KPI analysis, supplier performance evaluation, and operational reporting.

# %% [markdown]
# ## Supply Chain Operations Dataset

# %%
Supply_Chain_Operations_Dataset.head()
# Out:
#     Product    Supplier Warehouse Location  Quantity  Unit Price  Total Cost  \
# 0  Widget A  Alpha Corp        Warehouse 3        45       16.02      720.90
# 1  Widget A  Epsilon Co        Warehouse 1        85       23.99     2039.15
# 2  Widget A    Beta Ltd        Warehouse 1        74       32.09     2374.66
# 3  Widget B  Epsilon Co        Warehouse 2        38       25.21      957.98
# 4  Widget A    Beta Ltd        Warehouse 3        64       20.31     1299.84
#
#   Delivery Date
# 0    2025-06-05
# 1    2025-06-01
# 2    2025-06-18
# 3    2025-06-09
# 4    2025-06-05

# %%
Supply_Chain_Operations_Dataset.shape
# Out:
# (30, 7)

# %%
Supply_Chain_Operations_Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Product             30 non-null     object
#  1   Supplier            30 non-null     object
#  2   Warehouse Location  30 non-null     object
#  3   Quantity            30 non-null     int64
#  4   Unit Price          30 non-null     float64
#  5   Total Cost          30 non-null     float64
#  6   Delivery Date       30 non-null     object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.8+ KB

# %%
Supply_Chain_Operations_Dataset.isnull().sum()
# Out:
# Product               0
# Supplier              0
# Warehouse Location    0
# Quantity              0
# Unit Price            0
# Total Cost            0
# Delivery Date         0
# dtype: int64

# %%
numeric_columns = Supply_Chain_Operations_Dataset.select_dtypes(include=['number'])
print(numeric_columns.columns.tolist())
# Out:
# ['Quantity', 'Unit Price', 'Total Cost']

# %%
## Continuous Numerical Variables
continuous_variables = [
    'Quantity',
    'Unit Price',
    'Total Cost'
]

print("Continuous Numerical Variables:")
print(continuous_variables)
# Out:
# Continuous Numerical Variables:
# ['Quantity', 'Unit Price', 'Total Cost']

# %%
## Correlation Dataset
corr_data = Supply_Chain_Operations_Dataset[continuous_variables]

corr_data.head()
# Out:
#    Quantity  Unit Price  Total Cost
# 0        45       16.02      720.90
# 1        85       23.99     2039.15
# 2        74       32.09     2374.66
# 3        38       25.21      957.98
# 4        64       20.31     1299.84

# %%
## Correlation Matrix
correlation_matrix = corr_data.corr()

print(correlation_matrix)
# Out:
#             Quantity  Unit Price  Total Cost
# Quantity    1.000000   -0.171733    0.718121
# Unit Price -0.171733    1.000000    0.512211
# Total Cost  0.718121    0.512211    1.000000

# %%
## Correlation Heatmap
plt.figure(figsize=(6,5))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title("Correlation Matrix - Supply Chain Operations Dataset")

plt.show()

# %% [markdown]
# ## Correlation Analysis - Supply Chain Operations Dataset
#
# ### Observations
#
# 1. Quantity and Total Cost have a **strong positive correlation (0.72)**, indicating that larger order quantities generally lead to higher total costs.
#
# 2. Unit Price and Total Cost show a **moderate positive correlation (0.51)**, meaning higher-priced items contribute to increased total procurement cost.
#
# 3. Quantity and Unit Price have a **weak negative correlation (-0.17)**, suggesting that order quantity has very little relationship with unit price.
#
# ### Business Insight
#
# The total procurement cost is mainly influenced by both the quantity ordered and the unit price. Quantity has a stronger impact on total cost than unit price in this dataset.

# %%
## Business Logic Validation
print("Negative Quantity:",
      (Supply_Chain_Operations_Dataset['Quantity'] < 0).sum())

print("Negative Unit Price:",
      (Supply_Chain_Operations_Dataset['Unit Price'] < 0).sum())

print("Negative Total Cost:",
      (Supply_Chain_Operations_Dataset['Total Cost'] < 0).sum())

expected_total = (
    Supply_Chain_Operations_Dataset['Quantity'] *
    Supply_Chain_Operations_Dataset['Unit Price']
)

difference = (
    Supply_Chain_Operations_Dataset['Total Cost'] - expected_total
).abs()

print("Rows with Total Cost mismatch:", (difference > 0.01).sum())
# Out:
# Negative Quantity: 0
# Negative Unit Price: 0
# Negative Total Cost: 0
# Rows with Total Cost mismatch: 0

# %%
## Data Validation
Supply_Chain_Operations_Dataset['Delivery Date'] = pd.to_datetime(
    Supply_Chain_Operations_Dataset['Delivery Date'],
    errors='coerce'
)

# %%
Supply_Chain_Operations_Dataset[['Delivery Date']].isnull().sum()
# Out:
# Delivery Date    0
# dtype: int64

# %% [markdown]
# ## Reliability Conclusion
#
# The Supply Chain Operations dataset successfully passed data validation, missing value verification, duplicate checking, numerical variable validation, correlation analysis, business logic validation, and date validation.
#
# No missing values or duplicate records were found. Business rules were validated successfully, and the dataset is reliable for supply chain performance analysis, procurement monitoring, inventory planning, and operational reporting.

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Admin\Enterprise Procurement & Vendor Performance Analytics

# %%
datasets = {
    "vendor_invoice": vendor_invoice,
    "purchase_prices": purchase_prices,
    "vendor_sales_summary": vendor_sales_summary,
    "purchases": purchases,
    "begin_inventory": begin_inventory,
    "sales": sales,
    "end_inventory": end_inventory,
    "Procurement_KPI_Analysis_Dataset": Procurement_KPI_Analysis_Dataset,
    "purchase_orders": purchase_orders,
    "Supply_Chain_Operations_Dataset": Supply_Chain_Operations_Dataset
}

for name, data in datasets.items():
    print("\n" + "="*60)
    print(name)
    print("="*60)
    print(data.columns.tolist())
# Out:
# ...
# vendor_invoice
# ...
# ['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate', 'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval']
#
# ...
# purchase_prices
# ...
# ['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification', 'PurchasePrice', 'VendorNumber', 'VendorName']
#
# ...
# vendor_sales_summary
# ...
# ['VendorNumber', 'VendorName', 'Brand', 'Description', 'PurchasePrice', 'ActualPrice', 'Volume', 'TotalPurchaseQuantity', 'TotalPurchaseDollars', 'TotalSalesQuantity', 'TotalSalesPrice', 'TotalSalesDollars', 'TotalExciseTax', 'FreightCost', 'GrossProfit', 'ProfitMargin', 'StockTurnover', 'SalestoPurchaseRatio']
#
# ...
# purchases
# ...
# ['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber', 'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate', 'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification']
#
# ...
# begin_inventory
# ...
# ['InventoryId', 'Store', 'City', 'Brand', 'Description', 'Size', 'onHand', 'Price', 'startDate']
#
# ...
# sales
# ...

# %%
# %whos DataFrame
# Out:
# Variable                           Type         Data/Info
# ---------------------------------------------------------
# Procurement_KPI_Analysis_Dataset   DataFrame            PO_ID         Sup<...>\n[777 rows x 11 columns]
# Purchase_prices                    DataFrame           Brand             <...>n[12261 rows x 9 columns]
# Supply_Chain_Operations_Dataset    DataFrame         Product    Supplier <...>-25  \n29    2025-06-18
# begin_inventory                    DataFrame                   InventoryI<...>[206529 rows x 9 columns]
# corr_data                          DataFrame        Quantity  Unit Price <...>4       26.39     2480.66
# correlation_matrix                 DataFrame                Quantity  Uni<...>1    0.512211    1.000000
# df                                 DataFrame                   InventoryI<...>[20000 rows x 16 columns]
# end_inventory                      DataFrame                  InventoryId<...>[224489 rows x 9 columns]
# ...
